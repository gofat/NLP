# %%
# %pylab inline
# %precision 6
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['size']
# `%matplotlib` prevents importing * from pylab and numpy
# '%.6f'

# %%
import pandas as pd
import sklearn as skl
import nltk

# %%
pd.options.display.max_colwidth=100
np.set_printoptions(linewidth=140,edgeitems=10)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
rcParams['figure.figsize'] = (8.0, 5.0)

# %% [markdown]
# # Classification

# %%
from nltk.corpus import movie_reviews
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
len( movie_reviews.fileids() )
# Out:
# 2000

# %%
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]
np.random.seed(0)
random.shuffle(documents)

# %%
documents[0][1]
# Out:
# 'neg'

# %%
documents[0][0]
# Out:
# ['arnold',
#  'schwarzenegger',
#  'has',
#  'been',
#  'an',
#  'icon',
#  'for',
#  'action',
#  'enthusiasts',
#  ',',
#  'since',
#  'the',
#  'late',
#  '80',
#  "'",
#  's',
#  ',',
#  'but',
#  'lately',
#  'his',
#  'films',
#  'have',
#  'been',
#  'very',
#  'sloppy',
#  'and',
#  'the',
#  'one',
#  '-',
#  'liners',
#  'are',
#  'getting',
#  'worse',
#  '.',
#  'it',
#  "'",
#  's',
#  'hard',
#  'seeing',
#  'arnold',
#  'as',
#  'mr',
#  '.',
#  'freeze',
#  'in',
#  'batman',
#  'and',
#  'robin',
#  ',',
#  'especially',
#  'when',
#  'he',
#  'says',
#  'tons',
#  'of',
#  'ice',
#  'jokes',
#  ',',
#  'but',
#  'hey',
#  'he',
#  'got',
#  '15',
#  'million',
#  ',',
#  'what',
#  "'",
#  's',
#  'it',
#  'matter',
#  'to',
#  'him',
#  '?',
#  'once',
#  'again',
#  'arnold',
#  'has',
#  'signed',
#  'to',
#  'do',
#  'another',
#  'expensive',
#  'blockbuster',
#  ',',
#  'that',
#  'can',
#  "'",
#  't',
#  'compare',
#  'with',
#  'the',
#  'likes',
#  'of',
#  'the',
#  'terminator',
#  'series',
#  ',',
#  'true',
#  'lies',
#  'and',
#  'even',
#  'eraser',
#  '.',
#  'in',
#  'this',
#  'so',
#  'called',
#  'dark',
#  'thriller',
#  ',',
#  'the',
#  'devil',
#  '(',
#  'gabriel',
#  'byrne',
#  ')',
#  'has',
#  'come',
#  'upon',
#  'earth',
#  ',',
#  'to',
#  'impregnate',
#  'a',
#  'woman',
#  '(',
#  'robin',
#  'tunney',
#  ')',
#  'which',
#  'happens',
#  'every',
#  '1000',
#  'years',
#  ',',
#  'and',
#  'basically',
#  'destroy',
#  'the',
#  'world',
#  ',',
#  'but',
#  'apparently',
#  'god',
#  'has',
#  'chosen',
#  'one',
#  'man',
#  ',',
#  'and',
#  'that',
#  'one',
#  'man',
#  'is',
#  'jericho',
#  'cane',
#  '(',
#  'arnold',
#  'himself',
#  ')',
#  '.',
#  'with',
#  'the',
#  'help',
#  'of',
#  'a',
#  'trusty',
#  'sidekick',
#  '(',
#  'kevin',
#  'pollack',
#  ')',
#  ',',
#  'they',
#  'will',
#  'stop',
#  'at',
#  'nothing',
#  'to',
#  'let',
#  'the',
#  'devil',
#  'take',
#  'over',
#  'the',
#  'world',
#  '!',
#  'parts',
#  'of',
#  'this',
#  'are',
#  'actually',
#  'so',
#  'absurd',
#  ',',
#  'that',
#  'they',
#  'would',
#  'fit',
#  'right',
#  'in',
#  'with',
#  'dogma',
#  '.',
#  'yes',
#  ',',
#  'the',
#  'film',
#  'is',
#  'that',
#  'weak',
#  ',',
#  'but',
#  'it',
#  "'",
#  's',
#  'better',
#  'than',
#  'the',
#  'other',
#  'blockbuster',
#  'right',
#  'now',
#  '(',
#  'sleepy',
#  'hollow',
#  ')',
#  ',',
#  'but',
#  'it',
#  'makes',
#  'the',
#  'world',
#  'is',
#  'not',
#  'enough',
#  'look',
#  'like',
#  'a',
#  '4',
#  'star',
#  'film',
#  '.',
#  'anyway',
#  ',',
#  'this',
#  'definitely',
#  'doesn',
#  "'",
#  't',
#  'seem',
#  'like',
#  'an',
#  'arnold',
#  'movie',
#  '.',
#  'it',
#  'just',
#  'wasn',
#  "'",
#  't',
#  'the',
#  'type',
#  'of',
#  'film',
#  'you',
#  'can',
#  'see',
#  'him',
#  'doing',
#  '.',
#  'sure',
#  'he',
#  'gave',
#  'us',
#  'a',
#  'few',
#  'chuckles',
#  'with',
#  'his',
#  'well',
#  'known',
#  'one',
#  '-',
#  'liners',
#  ',',
#  'but',
#  'he',
#  'seemed',
#  'confused',
#  'as',
#  'to',
#  'where',
#  'his',
#  'character',
#  'and',
#  'the',
#  'film',
#  'was',
#  'going',
#  '.',
#  'it',
#  "'",
#  's',
#  'understandable',
#  ',',
#  'especially',
#  'when',
#  'the',
#  'ending',
#  'had',
#  'to',
#  'be',
#  'changed',
#  'according',
#  'to',
#  'some',
#  'sources',
#  '.',
#  'aside',
#  'form',
#  'that',
#  ',',
#  'he',
#  'still',
#  'walked',
#  'through',
#  'it',
#  ',',
#  'much',
#  'like',
#  'he',
#  'has',
#  'in',
#  'the',
#  'past',
#  'few',
#  'films',
#  '.',
#  'i',
#  "'",
#  'm',
#  'sorry',
#  'to',
#  'say',
#  'this',
#  'arnold',
#  'but',
#  'maybe',
#  'these',
#  'are',
#  'the',
#  'end',
#  'of',
#  'your',
#  'action',
#  'days',
#  '.',
#  'speaking',
#  'of',
#  'action',
#  ',',
#  'where',
#  'was',
#  'it',
#  'in',
#  'this',
#  'film',
#  '?',
#  'there',
#  'was',
#  'hardly',
#  'any',
#  'explosions',
#  'or',
#  'fights',
#  '.',
#  'the',
#  'devil',
#  'made',
#  'a',
#  'few',
#  'places',
#  'explode',
#  ',',
#  'but',
#  'arnold',
#  'wasn',
#  "'",
#  't',
#  'kicking',
#  'some',
#  'devil',
#  'butt',
#  '.',
#  'the',
#  'ending',
#  'was',
#  'changed',
#  'to',
#  'make',
#  'it',
#  'more',
#  'spiritual',
#  ',',
#  'which',
#  'undoubtedly',
#  'ruined',
#  'the',
#  'film',
#  '.',
#  'i',
#  'was',
#  'at',
#  'least',
#  'hoping',
#  'for',
#  'a',
#  'cool',
#  'ending',
#  'if',
#  'nothing',
#  'else',
#  'occurred',
#  ',',
#  'but',
#  'once',
#  'again',
#  'i',
#  'was',
#  'let',
#  'down',
#  '.',
#  'i',
#  'also',
#  'don',
#  "'",
#  't',
#  'know',
#  'why',
#  'the',
#  'film',
#  'took',
#  'so',
#  'long',
#  'and',
#  'cost',
#  'so',
#  'much',
#  '.',
#  'there',
#  'was',
#  'really',
#  'no',
#  'super',
#  'affects',
#  'at',
#  'all',
#  ',',
#  'unless',
#  'you',
#  'consider',
#  'an',
#  'invisible',
#  'devil',
#  ',',
#  'who',
#  'was',
#  'in',
#  'it',
#  'for',
#  '5',
#  'minutes',
#  'tops',
#  ',',
#  'worth',
#  'the',
#  'overpriced',
#  'budget',
#  '.',
#  'the',
#  'budget',
#  'should',
#  'have',
#  'gone',
#  'into',
#  'a',
#  'better',
#  'script',
#  ',',
#  'where',
#  'at',
#  'least',
#  'audiences',
#  'could',
#  'be',
#  'somewhat',
#  'entertained',
#  'instead',
#  'of',
#  'facing',
#  'boredom',
#  '.',
#  'it',
#  "'",
#  's',
#  'pitiful',
#  'to',
#  'see',
#  'how',
#  'scripts',
#  'like',
#  'these',
#  'get',
#  'bought',
#  'and',
#  'made',
#  'into',
#  'a',
#  'movie',
#  '.',
#  'do',
#  'they',
#  'even',
#  'read',
#  'these',
#  'things',
#  'anymore',
#  '?',
#  'it',
#  'sure',
#  'doesn',
#  "'",
#  't',
#  'seem',
#  'like',
#  'it',
#  '.',
#  'thankfully',
#  'gabriel',
#  "'",
#  's',
#  'performance',
#  'gave',
#  'some',
#  'light',
#  'to',
#  'this',
#  'poor',
#  'film',
#  '.',
#  'when',
#  'he',
#  'walks',
#  'down',
#  'the',
#  'street',
#  'searching',
#  'for',
#  'robin',
#  'tunney',
#  ',',
#  'you',
#  'can',
#  "'",
#  't',
#  'help',
#  'but',
#  'feel',
#  'that',
#  'he',
#  'looked',
#  'like',
#  'a',
#  'devil',
#  '.',
#  'the',
#  'guy',
#  'is',
#  'creepy',
#  'looking',
#  'anyway',
#  '!',
#  'when',
#  'it',
#  "'",
#  's',
#  'all',
#  'over',
#  ',',
#  'you',
#  "'",
#  're',
#  'just',
#  'glad',
#  'it',
#  "'",
#  's',
#  'the',
#  'end',
#  'of',
#  'the',
#  'movie',
#  '.',
#  'don',
#  "'",
#  't',
#  'bother',
#  'to',
#  'see',
#  'this',
#  ',',
#  'if',
#  'you',
#  "'",
#  're',
#  'expecting',
#  'a',
#  'solid',
#  'action',
#  'flick',
#  ',',
#  'because',
#  'it',
#  "'",
#  's',
#  'neither',
#  'solid',
#  'nor',
#  'does',
#  'it',
#  'have',
#  'action',
#  '.',
#  'it',
#  "'",
#  's',
#  'just',
#  'another',
#  'movie',
#  'that',
#  'we',
#  'are',
#  'suckered',
#  'in',
#  'to',
#  'seeing',
#  ',',
#  'due',
#  'to',
#  'a',
#  'strategic',
#  'marketing',
#  'campaign',
#  '.',
#  'save',
#  'your',
#  'money',
#  'and',
#  'see',
#  'the',
#  'world',
#  'is',
#  'not',
#  'enough',
#  'for',
#  'an',
#  'entertaining',
#  'experience',
#  '.']

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = [word for (word,count) in all_words.most_common(2000)]

# %%
word_features
# Out:
# [',',
#  'the',
#  '.',
#  'a',
#  'and',
#  'of',
#  'to',
#  "'",
#  'is',
#  'in',
#  's',
#  '"',
#  'it',
#  'that',
#  '-',
#  ')',
#  '(',
#  'as',
#  'with',
#  'for',
#  'his',
#  'this',
#  'film',
#  'i',
#  'he',
#  'but',
#  'on',
#  'are',
#  't',
#  'by',
#  'be',
#  'one',
#  'movie',
#  'an',
#  'who',
#  'not',
#  'you',
#  'from',
#  'at',
#  'was',
#  'have',
#  'they',
#  'has',
#  'her',
#  'all',
#  '?',
#  'there',
#  'like',
#  'so',
#  'out',
#  'about',
#  'up',
#  'more',
#  'what',
#  'when',
#  'which',
#  'or',
#  'she',
#  'their',
#  ':',
#  'some',
#  'just',
#  'can',
#  'if',
#  'we',
#  'him',
#  'into',
#  'even',
#  'only',
#  'than',
#  'no',
#  'good',
#  'time',
#  'most',
#  'its',
#  'will',
#  'story',
#  'would',
#  'been',
#  'much',
#  'character',
#  'also',
#  'get',
#  'other',
#  'do',
#  'two',
#  'well',
#  'them',
#  'very',
#  'characters',
#  ';',
#  'first',
#  '--',
#  'after',
#  'see',
#  '!',
#  'way',
#  'because',
#  'make',
#  'life',
#  'off',
#  'too',
#  'any',
#  'does',
#  'really',
#  'had',
#  'while',
#  'films',
#  'how',
#  'plot',
#  'little',
#  'where',
#  'people',
#  'over',
#  'could',
#  'then',
#  'me',
#  'scene',
#  'man',
#  'bad',
#  'my',
#  'never',
#  'being',
#  'best',
#  'these',
#  'don',
#  'new',
#  'doesn',
#  'scenes',
#  'many',
#  'director',
#  'such',
#  'were',
#  'know',
#  'movies',
#  'through',
#  'here',
#  'action',
#  'great',
#  're',
#  'another',
#  'love',
#  'go',
#  'made',
#  'us',
#  'big',
#  'end',
#  'something',
#  'back',
#  '*',
#  'still',
#  'world',
#  'seems',
#  'work',
#  'those',
#  'before',
#  'now',
#  'makes',
#  'however',
#  'between',
#  'few',
#  '/',
#  'down',
#  'every',
#  'though',
#  'better',
#  'real',
#  'audience',
#  'seen',
#  'enough',
#  'take',
#  'around',
#  'both',
#  'going',
#  'performance',
#  'year',
#  'why',
#  'role',
#  'should',
#  'isn',
#  'old',
#  'same',
#  'gets',
#  'your',
#  'may',
#  'things',
#  'think',
#  'years',
#  'last',
#  'funny',
#  'comedy',
#  'actually',
#  've',
#  'long',
#  'look',
#  'almost',
#  'own',
#  'thing',
#  'fact',
#  'nothing',
#  'say',
#  'john',
#  'right',
#  'although',
#  'played',
#  'find',
#  'script',
#  'come',
#  'ever',
#  'cast',
#  'since',
#  'did',
#  'star',
#  'plays',
#  'young',
#  'show',
#  'comes',
#  'm',
#  'part',
#  'original',
#  'actors',
#  'screen',
#  'without',
#  'again',
#  'acting',
#  'three',
#  'day',
#  'each',
#  'point',
#  'lot',
#  'least',
#  'takes',
#  'guy',
#  'quite',
#  'himself',
#  'during',
#  'away',
#  'family',
#  'effects',
#  'course',
#  'goes',
#  'minutes',
#  'interesting',
#  'far',
#  'might',
#  'high',
#  'once',
#  'rather',
#  'anything',
#  'must',
#  'place',
#  'set',
#  'yet',
#  'watch',
#  'd',
#  'making',
#  'our',
#  'wife',
#  'hard',
#  'always',
#  'fun',
#  'didn',
#  'll',
#  'special',
#  'seem',
#  'bit',
#  'times',
#  'trying',
#  'hollywood',
#  'instead',
#  'give',
#  'want',
#  'picture',
#  'kind',
#  'american',
#  'job',
#  'sense',
#  'woman',
#  'home',
#  'having',
#  'series',
#  'actor',
#  'probably',
#  'help',
#  'half',
#  'along',
#  'men',
#  'everything',
#  'pretty',
#  'becomes',
#  'sure',
#  'black',
#  'together',
#  'dialogue',
#  'money',
#  'become',
#  'gives',
#  'given',
#  'looking',
#  'whole',
#  'watching',
#  'father',
#  '`',
#  'feel',
#  'everyone',
#  'music',
#  'wants',
#  'sex',
#  'done',
#  'less',
#  'horror',
#  'got',
#  'death',
#  'perhaps',
#  'city',
#  'next',
#  'especially',
#  'play',
#  'girl',
#  'mind',
#  '10',
#  'moments',
#  'looks',
#  'completely',
#  '2',
#  'reason',
#  'mother',
#  'whose',
#  'night',
#  'line',
#  'human',
#  'rest',
#  'until',
#  'performances',
#  'different',
#  'small',
#  'james',
#  'evil',
#  'simply',
#  'couple',
#  'put',
#  'let',
#  'anyone',
#  'ending',
#  'case',
#  'several',
#  'dead',
#  'michael',
#  'left',
#  'thought',
#  'school',
#  'true',
#  'shows',
#  'humor',
#  'written',
#  'lost',
#  'itself',
#  'friend',
#  'entire',
#  'getting',
#  'town',
#  'turns',
#  'soon',
#  'second',
#  'someone',
#  'stars',
#  'main',
#  'use',
#  'found',
#  'friends',
#  'problem',
#  'tv',
#  'top',
#  'begins',
#  'name',
#  'called',
#  'comic',
#  'based',
#  'david',
#  'else',
#  'head',
#  'either',
#  'idea',
#  'wrong',
#  'unfortunately',
#  'later',
#  'final',
#  'hand',
#  'alien',
#  'house',
#  'group',
#  'full',
#  'used',
#  'tries',
#  'often',
#  'against',
#  'war',
#  'sequence',
#  'keep',
#  'turn',
#  'behind',
#  'named',
#  'boy',
#  'playing',
#  'certainly',
#  'live',
#  'believe',
#  'works',
#  'under',
#  'relationship',
#  'face',
#  'hour',
#  'run',
#  'style',
#  'said',
#  'despite',
#  'person',
#  'finally',
#  'shot',
#  'doing',
#  'book',
#  'tell',
#  'maybe',
#  'nice',
#  'son',
#  'perfect',
#  'side',
#  'able',
#  'seeing',
#  'finds',
#  'children',
#  'days',
#  'past',
#  'summer',
#  'camera',
#  'won',
#  'including',
#  'mr',
#  'kids',
#  'lives',
#  'directed',
#  'game',
#  'moment',
#  'running',
#  'fight',
#  'supposed',
#  'video',
#  'car',
#  'joe',
#  'matter',
#  'kevin',
#  'lines',
#  '=',
#  'worth',
#  'daughter',
#  'earth',
#  'need',
#  'starts',
#  'entertaining',
#  'white',
#  'writer',
#  'dark',
#  'start',
#  'short',
#  'self',
#  'worst',
#  'nearly',
#  'try',
#  'opening',
#  'upon',
#  'care',
#  'early',
#  'violence',
#  'throughout',
#  'team',
#  'example',
#  'production',
#  'beautiful',
#  'title',
#  'exactly',
#  'jack',
#  'review',
#  'major',
#  'drama',
#  'problems',
#  '&',
#  'sequences',
#  'known',
#  'version',
#  'obvious',
#  'screenplay',
#  'wasn',
#  'robert',
#  'killer',
#  'disney',
#  'classic',
#  'close',
#  'already',
#  'others',
#  'hit',
#  'kill',
#  'deep',
#  'simple',
#  'order',
#  'fine',
#  'act',
#  'five',
#  'roles',
#  'heart',
#  'jackie',
#  'direction',
#  'themselves',
#  'eyes',
#  'four',
#  'sort',
#  'question',
#  'sometimes',
#  'knows',
#  'supporting',
#  'women',
#  'coming',
#  'voice',
#  'truly',
#  'jokes',
#  'computer',
#  'save',
#  'child',
#  'o',
#  '1',
#  'tom',
#  'level',
#  'boring',
#  'body',
#  'genre',
#  'stop',
#  'brother',
#  'strong',
#  'guys',
#  'room',
#  'space',
#  'lee',
#  'ends',
#  'beginning',
#  'york',
#  'ship',
#  'attempt',
#  'thriller',
#  'scream',
#  'peter',
#  'husband',
#  'aren',
#  'fiction',
#  'hero',
#  'happens',
#  'novel',
#  'hope',
#  'note',
#  'yes',
#  'says',
#  'king',
#  'tells',
#  'quickly',
#  'oscar',
#  'dog',
#  'romantic',
#  'saw',
#  'stupid',
#  'possible',
#  'lead',
#  'career',
#  'murder',
#  'god',
#  'manages',
#  'extremely',
#  'wonder',
#  'mostly',
#  'future',
#  'particularly',
#  'sound',
#  'fans',
#  'worse',
#  'piece',
#  'de',
#  'involving',
#  'planet',
#  'paul',
#  'appears',
#  'involved',
#  'none',
#  'taking',
#  'hours',
#  'laugh',
#  'mean',
#  'police',
#  'sets',
#  'co',
#  'attention',
#  'hell',
#  'eventually',
#  'falls',
#  'fall',
#  'single',
#  'material',
#  'emotional',
#  'late',
#  'power',
#  'result',
#  'lack',
#  'dr',
#  'van',
#  'smith',
#  'elements',
#  'meet',
#  'science',
#  'experience',
#  'wild',
#  'bring',
#  'living',
#  'theater',
#  'interest',
#  'word',
#  'leads',
#  'feature',
#  'battle',
#  'alone',
#  'girls',
#  'george',
#  'obviously',
#  'usually',
#  'within',
#  'enjoy',
#  'among',
#  'guess',
#  'taken',
#  'laughs',
#  'aliens',
#  'feeling',
#  'talk',
#  'talent',
#  'chance',
#  'easy',
#  'number',
#  'middle',
#  '3',
#  'attempts',
#  'across',
#  'needs',
#  'chris',
#  'happen',
#  'television',
#  'form',
#  'poor',
#  'deal',
#  'killed',
#  'release',
#  'forced',
#  'viewer',
#  'girlfriend',
#  'wonderful',
#  'whether',
#  'feels',
#  'success',
#  'premise',
#  'except',
#  'serious',
#  'tale',
#  'oh',
#  'expect',
#  'light',
#  'features',
#  'meets',
#  'important',
#  'happy',
#  'history',
#  'words',
#  'leave',
#  'type',
#  'turned',
#  'parents',
#  'impressive',
#  'giving',
#  'released',
#  'art',
#  'call',
#  'crew',
#  'working',
#  'mission',
#  'score',
#  'told',
#  'seemed',
#  'america',
#  'recent',
#  'entertainment',
#  'basically',
#  'robin',
#  '$',
#  'surprise',
#  'ryan',
#  'apparently',
#  'easily',
#  'cop',
#  'williams',
#  'crime',
#  'office',
#  'change',
#  'cool',
#  'stuff',
#  'parts',
#  'somehow',
#  'sequel',
#  'william',
#  'cut',
#  'die',
#  'jones',
#  'credits',
#  'batman',
#  'suspense',
#  'brings',
#  'events',
#  'reality',
#  'whom',
#  'local',
#  'hilarious',
#  'difficult',
#  'near',
#  'writing',
#  'using',
#  'went',
#  'talking',
#  'remember',
#  'straight',
#  'ago',
#  'certain',
#  'ben',
#  'wouldn',
#  'kid',
#  'blood',
#  'mystery',
#  'slow',
#  'am',
#  'fast',
#  'complete',
#  'popular',
#  'effective',
#  'red',
#  'flick',
#  'due',
#  'runs',
#  'gone',
#  'quality',
#  'presence',
#  'return',
#  'brothers',
#  'age',
#  'dramatic',
#  'filmmakers',
#  'general',
#  'business',
#  'sexual',
#  'rock',
#  'present',
#  'anyway',
#  'uses',
#  'surprisingly',
#  '4',
#  'personal',
#  'smart',
#  'figure',
#  'decides',
#  'begin',
#  'couldn',
#  'annoying',
#  'ways',
#  'shots',
#  'somewhat',
#  'rich',
#  'law',
#  'minute',
#  'former',
#  'similar',
#  'water',
#  'jim',
#  'previous',
#  'harry',
#  'absolutely',
#  'motion',
#  'successful',
#  'project',
#  'read',
#  'follow',
#  'strange',
#  'came',
#  'million',
#  'amazing',
#  'third',
#  'clear',
#  'romance',
#  'starring',
#  'excellent',
#  'familiar',
#  'intelligent',
#  'secret',
#  'latest',
#  'prison',
#  'budget',
#  'party',
#  'eye',
#  'company',
#  'actress',
#  'means',
#  'powerful',
#  'predictable',
#  'bob',
#  'nor',
#  'towards',
#  'leaves',
#  'beyond',
#  'visual',
#  'r',
#  'villain',
#  'nature',
#  'following',
#  'leaving',
#  'wars',
#  'sam',
#  'animated',
#  'myself',
#  'b',
#  'low',
#  'bill',
#  'filled',
#  'cinema',
#  'box',
#  'country',
#  'questions',
#  'message',
#  'moving',
#  'herself',
#  'definitely',
#  'large',
#  'martin',
#  'add',
#  'create',
#  'clever',
#  'usual',
#  'situation',
#  'stories',
#  'giant',
#  'ones',
#  'murphy',
#  'brilliant',
#  'felt',
#  'doubt',
#  'opens',
#  'break',
#  'scary',
#  'drug',
#  'thinking',
#  'bunch',
#  'solid',
#  'effect',
#  'move',
#  'learn',
#  'seriously',
#  'force',
#  'potential',
#  'saying',
#  'above',
#  'follows',
#  'class',
#  'huge',
#  'plan',
#  'agent',
#  'created',
#  'unlike',
#  'perfectly',
#  'non',
#  'married',
#  'mark',
#  'sweet',
#  'pay',
#  'ex',
#  'realize',
#  'audiences',
#  'subject',
#  'dream',
#  'enjoyable',
#  'understand',
#  'scott',
#  'decent',
#  'likely',
#  'view',
#  'took',
#  'happened',
#  'immediately',
#  'cameron',
#  'points',
#  'viewers',
#  'open',
#  'heard',
#  'studio',
#  'truman',
#  'e',
#  'bruce',
#  'frank',
#  'private',
#  'richard',
#  'fails',
#  'stay',
#  'cold',
#  'impossible',
#  'overall',
#  'merely',
#  'exciting',
#  'chase',
#  'carter',
#  'free',
#  'gun',
#  'wanted',
#  'neither',
#  'mess',
#  'appear',
#  'ten',
#  '+',
#  'escape',
#  'fan',
#  'ultimately',
#  'modern',
#  'inside',
#  'stone',
#  'brought',
#  'wedding',
#  'haven',
#  'l',
#  'trek',
#  'favorite',
#  'trouble',
#  '5',
#  'allen',
#  'otherwise',
#  'tim',
#  'dumb',
#  'liked',
#  'society',
#  'bond',
#  'particular',
#  'various',
#  'stand',
#  'musical',
#  'political',
#  'talented',
#  'west',
#  'state',
#  'keeps',
#  'u',
#  'situations',
#  'silly',
#  'park',
#  'english',
#  'steve',
#  'rating',
#  'air',
#  'slightly',
#  'teen',
#  'truth',
#  'spend',
#  'joke',
#  'element',
#  'key',
#  'eddie',
#  'biggest',
#  'government',
#  'focus',
#  'members',
#  'effort',
#  'earlier',
#  'today',
#  'purpose',
#  'hands',
#  'soundtrack',
#  'chan',
#  'offers',
#  'max',
#  'memorable',
#  'six',
#  'cannot',
#  'showing',
#  'totally',
#  'rated',
#  'heavy',
#  'mars',
#  'woody',
#  'fi',
#  'control',
#  'credit',
#  'sci',
#  'wait',
#  'ideas',
#  'sit',
#  'sister',
#  ...]

# %%
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
print(document_features(movie_reviews.words('pos/cv957_8737.txt')))
# Out:
# {'contains(dramatic)': False, 'contains(devil)': False, 'contains(forces)': False, 'contains(ride)': False, 'contains(sent)': False, 'contains(artist)': False, 'contains(set)': False, 'contains(never)': True, 'contains(thanks)': False, 'contains(wife)': True, 'contains(later)': False, 'contains(bloody)': False, 'contains(walk)': False, 'contains(sub)': False, 'contains(gone)': False, 'contains(thomas)': False, 'contains(probably)': False, 'contains(fault)': False, 'contains(taken)': False, 'contains(complex)': False, 'contains(include)': False, 'contains(for)': True, 'contains(stupid)': False, 'contains(use)': False, 'contains(spice)': False, 'contains(harry)': False, 'contains(evil)': False, 'contains(look)': True, 'contains(truly)': False, 'contains(television)': False, 'contains(hill)': False, 'contains(changed)': False, 'contains(feature)': False, 'contains(faces)': False, 'contains(wonderfully)': False, 'contains(cinematic)': False, 'contains(damon)': False, 'contains(explain)': False, 'contains(just)': True, 'contains(filmmaking)': False, 'contains(george)': False, 'contains(bug)': False, 'contains(doubt)': False, 'contains(john)': False, 'contains(spectacular)': False, 'contains(buy)': False, 'contains(brother)': False, 'contains(succeeds)': False, 'contains(features)': True, 'contains(decade)': False, 'contains(fiction)': False, 'contains(done)': False, 'contains(appealing)': False, 'contains(lacks)': False, 'contains(laugh)': True, 'contains(x)': False, 'contains(apart)': False, 'contains(hilarious)': True, 'contains(called)': False, 'contains(cares)': False, 'contains(there)': True, 'contains(jones)': False, 'contains(rent)': False, 'contains(another)': False, 'contains(kelly)': False, 'contains(find)': False, 'contains(jackson)': False, 'contains(compelling)': False, 'contains(create)': False, 'contains(clever)': False, 'contains(keeping)': False, 'contains(am)': False, 'contains(in)': True, 'contains(followed)': False, 'contains(doing)': False, 'contains(task)': False, 'contains(things)': True, 'contains(honest)': False, 'contains(1)': False, 'contains(ago)': False, 'contains(critics)': False, 'contains(mediocre)': False, 'contains(search)': False, 'contains(might)': False, 'contains(frame)': False, 'contains(else)': False, 'contains(beginning)': False, 'contains(appearance)': False, 'contains(vampire)': False, 'contains(lot)': False, 'contains(isn)': False, 'contains(cool)': False, 'contains(more)': False, 'contains(roberts)': False, 'contains(hell)': False, 'contains(fate)': False, 'contains(actually)': True, 'contains(13)': False, 'contains(campbell)': False, 'contains(loved)': False, 'contains(aspects)': False, 'contains(opening)': False, 'contains(lose)': False, 'contains(girlfriend)': True, 'contains(sexual)': False, 'contains(which)': True, 'contains(moore)': False, 'contains(through)': False, 'contains(carrey)': False, 'contains(jane)': False, 'contains(front)': False, 'contains(goal)': False, 'contains(bright)': False, 'contains(development)': False, 'contains(life)': False, 'contains(watch)': True, 'contains(surprised)': False, 'contains(like)': True, 'contains(least)': True, 'contains(girl)': False, 'contains(final)': False, 'contains(gangster)': True, 'contains(floor)': False, 'contains(these)': False, 'contains(growing)': False, 'contains(editing)': False, 'contains(model)': False, 'contains(though)': False, 'contains(interested)': False, 'contains(shooting)': False, 'contains(manages)': False, 'contains(carpenter)': False, 'contains(cut)': False, 'contains(quality)': False, 'contains(revenge)': False, 'contains(puts)': False, 'contains(pg)': False, 'contains(air)': False, 'contains(attempt)': False, 'contains(mouth)': False, 'contains(ship)': False, 'contains(l)': False, 'contains(central)': False, 'contains(toy)': False, 'contains(answer)': False, 'contains(jeff)': False, 'contains(situations)': False, 'contains(meet)': False, 'contains(talents)': False, 'contains(hurt)': False, 'contains(leave)': Fa ...

# %%
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.77

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#    contains(outstanding) = True              pos : neg    =     13.3 : 1.0
#          contains(damon) = True              pos : neg    =     11.5 : 1.0
#         contains(seagal) = True              neg : pos    =      8.1 : 1.0
#    contains(wonderfully) = True              pos : neg    =      6.8 : 1.0
#           contains(lame) = True              neg : pos    =      6.1 : 1.0

# %% [markdown]
# Quality metrics:
# accuracy
#
# It is misleading in web search, where most documents are irrelevant.
# Classifier, always labelling document as irrelevant gives almost 100% accuracy.
#
# * TP, FP, TN, FN
# * Precision = TP/(labelled Positive) = TP/(TP+FP)
# * Recall = TP/(really Positive) = TP/(TP+FN)
# * F-Measure (or F-Score) - harmonic mean of the precision and recall: (2 × Precision × Recall) / (Precision + Recall).

# %% [markdown]
# confusion matrix

# %% [markdown]
# cross-Validation
#  * more economic use of data
#  * allows to see how performance varies with training set

# %% [markdown]
# # Part of speech tagging

# %%
from nltk.corpus import brown
suffix_fdist = nltk.FreqDist()
for word in brown.words():
    word = word.lower()
    suffix_fdist[word[-1:]] += 1
    suffix_fdist[word[-2:]] += 1
    suffix_fdist[word[-3:]] += 1

# %%
suffix_fdist['es']
# Out:
# 22408

# %%
common_suffixes = [suffix for (suffix, count) in suffix_fdist.most_common(100)]
print(common_suffixes)
# Out:
# ['e', ',', '.', 's', 'd', 't', 'he', 'n', 'a', 'of', 'the', 'y', 'r', 'to', 'in', 'f', 'o', 'ed', 'nd', 'is', 'on', 'l', 'g', 'and', 'ng', 'er', 'as', 'ing', 'h', 'at', 'es', 'or', 're', 'it', '``', 'an', "''", 'm', ';', 'i', 'ly', 'ion', 'en', 'al', '?', 'nt', 'be', 'hat', 'st', 'his', 'th', 'll', 'le', 'ce', 'by', 'ts', 'me', 've', "'", 'se', 'ut', 'was', 'for', 'ent', 'ch', 'k', 'w', 'ld', '`', 'rs', 'ted', 'ere', 'her', 'ne', 'ns', 'ith', 'ad', 'ry', ')', '(', 'te', '--', 'ay', 'ty', 'ot', 'p', 'nce', "'s", 'ter', 'om', 'ss', ':', 'we', 'are', 'c', 'ers', 'uld', 'had', 'so', 'ey']

# %%
def pos_features(word):
    features = {}
    for suffix in common_suffixes:
         features['endswith({})'.format(suffix)] = word.lower().endswith(suffix)
    return features

# %%
tagged_words = brown.tagged_words(categories='news')
featuresets = [(pos_features(n), g) for (n,g) in tagged_words]

# %%
np.random.shuffle(featuresets)

# %%
train_set, test_set = featuresets[:1000], featuresets[1000:2000]

# %%
classifier = nltk.DecisionTreeClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.570000

# %%
pos_features('cats')
# Out:
# {"endswith('')": False,
#  "endswith(')": False,
#  "endswith('s)": False,
#  'endswith(()': False,
#  'endswith())': False,
#  'endswith(,)': False,
#  'endswith(--)': False,
#  'endswith(.)': False,
#  'endswith(:)': False,
#  'endswith(;)': False,
#  'endswith(?)': False,
#  'endswith(`)': False,
#  'endswith(``)': False,
#  'endswith(a)': False,
#  'endswith(ad)': False,
#  'endswith(al)': False,
#  'endswith(an)': False,
#  'endswith(and)': False,
#  'endswith(are)': False,
#  'endswith(as)': False,
#  'endswith(at)': False,
#  'endswith(ay)': False,
#  'endswith(be)': False,
#  'endswith(by)': False,
#  'endswith(c)': False,
#  'endswith(ce)': False,
#  'endswith(ch)': False,
#  'endswith(d)': False,
#  'endswith(e)': False,
#  'endswith(ed)': False,
#  'endswith(en)': False,
#  'endswith(ent)': False,
#  'endswith(er)': False,
#  'endswith(ere)': False,
#  'endswith(ers)': False,
#  'endswith(es)': False,
#  'endswith(ey)': False,
#  'endswith(f)': False,
#  'endswith(for)': False,
#  'endswith(g)': False,
#  'endswith(h)': False,
#  'endswith(had)': False,
#  'endswith(hat)': False,
#  'endswith(he)': False,
#  'endswith(her)': False,
#  'endswith(his)': False,
#  'endswith(i)': False,
#  'endswith(in)': False,
#  'endswith(ing)': False,
#  'endswith(ion)': False,
#  'endswith(is)': False,
#  'endswith(it)': False,
#  'endswith(ith)': False,
#  'endswith(k)': False,
#  'endswith(l)': False,
#  'endswith(ld)': False,
#  'endswith(le)': False,
#  'endswith(ll)': False,
#  'endswith(ly)': False,
#  'endswith(m)': False,
#  'endswith(me)': False,
#  'endswith(n)': False,
#  'endswith(nce)': False,
#  'endswith(nd)': False,
#  'endswith(ne)': False,
#  'endswith(ng)': False,
#  'endswith(ns)': False,
#  'endswith(nt)': False,
#  'endswith(o)': False,
#  'endswith(of)': False,
#  'endswith(om)': False,
#  'endswith(on)': False,
#  'endswith(or)': False,
#  'endswith(ot)': False,
#  'endswith(p)': False,
#  'endswith(r)': False,
#  'endswith(re)': False,
#  'endswith(rs)': False,
#  'endswith(ry)': False,
#  'endswith(s)': True,
#  'endswith(se)': False,
#  'endswith(so)': False,
#  'endswith(ss)': False,
#  'endswith(st)': False,
#  'endswith(t)': False,
#  'endswith(te)': False,
#  'endswith(ted)': False,
#  'endswith(ter)': False,
#  'endswith(th)': False,
#  'endswith(the)': False,
#  'endswith(to)': False,
#  'endswith(ts)': True,
#  'endswith(ty)': False,
#  'endswith(uld)': False,
#  'endswith(ut)': False,
#  'endswith(ve)': False,
#  'endswith(w)': False,
#  'endswith(was)': False,
#  'endswith(we)': False,
#  'endswith(y)': False}

# %%
classifier.classify(pos_features('cats'))
# Out:
# 'NNS'

# %%
classifier.classify(pos_features('walked'))
# Out:
# 'VBD'

# %%
print(classifier.pseudocode(depth=4))
# Out:
# if endswith(he) == False:
#   if endswith(,) == False:
#     if endswith(s) == False:
#       if endswith(.) == False: return 'VBD'
#       if endswith(.) == True: return '.'
#     if endswith(s) == True:
#       if endswith(was) == False: return 'NNS-TL'
#       if endswith(was) == True: return 'BEDZ'
#   if endswith(,) == True: return ','
# if endswith(he) == True:
#   if endswith(the) == False: return 'PPS'
#   if endswith(the) == True: return 'AT'

# %%
def pos_features(sentence, i): 
    features = {"suffix(1)": sentence[i][-1:],
                "suffix(2)": sentence[i][-2:],
                "suffix(3)": sentence[i][-3:]}
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    return features

# %%
pos_features(brown.sents()[0], 8)
# Out:
# {'prev-word': 'an', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion'}

# %%
tagged_sents = brown.tagged_sents(categories='news')
featuresets = []
for tagged_sent in tagged_sents:
    untagged_sent = nltk.tag.untag(tagged_sent)
    for i, (word, tag) in enumerate(tagged_sent):
         featuresets.append( (pos_features(untagged_sent, i), tag) )

size = int(len(featuresets) * 0.5)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)

nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.757464

# %% [markdown]
# greedy sequence classification

# %%
posts = nltk.corpus.nps_chat.xml_posts()[:10000]

# %%
set([post.get('class') for post in posts])
# Out:
# {'Accept',
#  'Bye',
#  'Clarify',
#  'Continuer',
#  'Emotion',
#  'Emphasis',
#  'Greet',
#  'Other',
#  'Reject',
#  'Statement',
#  'System',
#  'nAnswer',
#  'whQuestion',
#  'yAnswer',
#  'ynQuestion'}

# %%
def dialogue_act_features(post):
    features = {}
    for word in nltk.word_tokenize(post):
        features['contains({})'.format(word.lower())] = True
    return feature

# %%
featuresets = [(dialogue_act_features(post.text), post.get('class'))
                    for post in posts]
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-4dec31de13e1> in <module>()
#       1 featuresets = [(dialogue_act_features(post.text), post.get('class'))
# ----> 2                     for post in posts]
#       3 size = int(len(featuresets) * 0.1)
#       4 train_set, test_set = featuresets[size:], featuresets[:size]
#       5 classifier = nltk.NaiveBayesClassifier.train(train_set)
#
# <ipython-input-126-4dec31de13e1> in <listcomp>(.0)
#       1 featuresets = [(dialogue_act_features(post.text), post.get('class'))
# ----> 2                     for post in posts]
#       3 size = int(len(featuresets) * 0.1)
#       4 train_set, test_set = featuresets[size:], featuresets[:size]
#       5 classifier = nltk.NaiveBayesClassifier.train(train_set)
#
# <ipython-input-125-8dc6a1cf7304> in dialogue_act_features(post)
#       3     for word in nltk.word_tokenize(post):
#       4         features['contains({})'.format(word.lower())] = True
# ----> 5     return feature
#
# NameError: name 'feature' is not defined

# %% [markdown]
# # Dialog act types

# %%
posts = nltk.corpus.nps_chat.xml_posts()[:10000]

# %%
def dialogue_act_features(post):
    features = {}
    for word in nltk.word_tokenize(post):
        features['contains({})'.format(word.lower())] = True
    return features

# %%
featuresets = [(dialogue_act_features(post.text), post.get('class'))
               for post in posts]
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))

# %%
set([cl for (post,cl) in featuresets])

# %% [markdown]
# # Textual Entailment

# %% [markdown]
# Challenge 3, Pair 34 (True)
#
# T: Parviz Davudi was representing Iran at a meeting of the Shanghai Co-operation Organisation (SCO), the fledgling association that binds Russia, China and four former Soviet republics of central Asia together to fight terrorism.
#
# H: China is a member of SCO.
#
# Challenge 3, Pair 81 (False)
#
# T: According to NC Articles of Organization, the members of LLC company are H. Nelson Beavers, III, H. Chester Beavers and Jennie Beavers Stewart.
#
# H: Jennie Beavers Stewart is a share-holder of Carolina Analytical Laboratory.
